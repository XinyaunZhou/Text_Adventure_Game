# %%
"""
Crated on Oct 25th 2021

Author: Xinyuan Zhou
"""

"""
This is a game base on the movie Harry Potter and the Chamber of Secrets 
(2002). The plot will unfold after five victims have been petrified by Basilisk, 
the king of Serpents. Harry Potter has learned that Myrtle and 50 years ago the 
Chamber of Secrets incident is related and will investigate on it.

In this game, you will substitute into the perspective of Harry Potter and try 
to solve this crisis.

Good Luck!
"""



# Start the game
def start():
    print("""
It's a day after the Christmas holidays, you are in the main castle and walking 
down the hallway to the second floor.""")
    input(prompt = "<Please press the enter to start>\n")
    hallway_1()
    
# Stage 1: Hallway
def hallway_1():
    print("""
When you get to the second floor of the castle, you see the floor full of water.
How will you respond to this strange sight?
    A: Follow the water trail to check
    B: Return to the dormitory \n""")
    
    choice_1 = input(prompt = "> Please enter your answer \n")
    choice_1 = choice_1.casefold()
    
    if choice_1.lower() == 'a':
        print("""
Following the water marks you came to a female bathroom.

You enter the bathroom and faintly hear a moan coming from the left. When you
look around, you find a row of toilet cubicles on the left side of the room 
and a circle of sinks directly in front of you.""")
        bathroom_1() # Move to next stage
        
    elif 'follow' in choice_1 or 'water' in choice_1:
        print("""
Following the water marks you came to a female bathroom.

You enter the bathroom and faintly hear a moan coming from the left. When you
look around, you find a row of toilet cubicles on the left side of the room 
and a circle of sinks directly in front of you.""")
        bathroom_1() # Move to next stage
        
    elif choice_1.lower() == 'b':
        print("""
You return to your dormitory and get to knoe the disappearance of Ron's sister, 
Ginny Weasley. Go back to the hallway to check it out.""")
        hallway_1() # Back to hallway
        
    elif 'return' in choice_1 or 'dormitory' in choice_1:
        print("""
You return to your dormitory to learn of the disappearance of Ron's sister, 
Ginny Weasley. Go back to the hallway to check it out.""")
        hallway_1() # Back to hallway
        
    else:
        print("Unable to read the answer! Please enter again.")
        hallway_1() # Back to the question
        

# Stage 2-1: Bathroom       
def bathroom_1():
    print("""
Now, you will choose to investigate the ___:
    A: Left
    B: Middle\n""")
    
    choice_2 = input(prompt = "> Please enter your answer \n")
    choice_2 = choice_2.casefold()
    
    # Choose to go to the left
    if choice_2.lower() == 'a' or 'left' in choice_2:
        print("""
There are four cubicles. Which door would you open based on your intuition? """)
        
        # Myrtle will appear in a random cubicle
        import random

        myrtle = random.randint(1,4)
        
        # User has 3 times to guesses
        guesses = 3

        while guesses > 0:
            choice_3 = input(prompt = """
            > Please choose a digital number from 1 to 4 \n""")
            choice_3 = choice_3.casefold()
    
            try:
                choice_3 = int(choice_3)
        
            except:
                print("It's not a digital number! Please try again.\n")
                
            # Start the guesses
            if choice_3 == myrtle:
                print("""
Open the door, and you find Myrtle, who is crying. She was thrown a diary and 
felt insulted, so she let out her anger and flooded the washroom.

You pick up the diary and ask her what happened to the Chamber of Secrets back 
then. Myrtle tells you that she only remembers seeing a pair of yellow eyes and 
that they ended up in the middle of the sink.

**Got the clue: the entrance is probably around the sink in middle.**\n""")
                bathroom_1() # Get the clue and back to bethroom_1
                break
        
            elif choice_3 != myrtle:
                guesses -= 1
                
                # User input should between 1 to 4
                if guesses > 0 and choice_3 < 5:
                    print(f"""
*It's not the right one. You have {guesses} chances left!\n""")
                    
                elif choice_3 >=5:
                    print("It's only 4 cubicles. Please try from 1 to 4! ")
        
                elif guesses == 0:
                    print(f"""
Hearing the commotion, Myrtle came out from the cubicle No.{myrtle} to check.
She was thrown a diary and felt insulted, so she let out her anger and flooded
the washroom.

You pick up the diary and ask her for clues to the Chamber of Secrets back then. 
Myrtle tells you that she only remembers seeing a pair of yellow eyes and that
they ended up in the middle of the sink.

**Got the clues: the entrance is probably around the sink in middle.**\n""")
                    bathroom_1() # Get the clue and back to bethroom_1
        
            # Didn't get the right answer
            else:
                print("Unable to read the answer! Please enter again.")
                bathroom_1() # Back to the question
                
                
   # Choose to go to the middle             
    elif choice_2.lower() == 'b' or 'middle' in choice_2:
        print("""
You walk towards the middle sink. Where do you think you should investigate?
    A: The bottom of the sink
    B: The faucet""")
        choice_4 = input(prompt = "<Please press the enter to start>\n")
        choice_4 = choice_4.casefold()
        
        if choice_4.lower() == 'a':
            print("""
Nothing special; it just looks like it's hollow inside. 
Please investigate again.""")
            bathroom_1() # Didn't find the entrance
            
        elif 'bottom' in choice_4 or 'sink' in choice_4:
            print("""
Nothing special; it just looks like it's hollow inside.
Please investigate again""")
            bathroom_1() # Didn't find the entrance
        
        elif choice_4.lower() == 'b' or 'faucet' in choice_4:
            print("""
Interesting!
You find a serpentine seal and realize you have found the mechanism.""")
            bathroom_2() # Move to next stage
            
        else:
            print("Unable to read the answer! Please enter again.")
            bathroom_1() # Back to the question
            
    else:
        print("Unable to read the answer! Please enter again.")
        bathroom_1() # Back to the question

# Stage 2-2: Charms       
def bathroom_2():
    print("""
Which way do you want to use to open this mechanism?
    A: Speak in Parseltongue
    B: Use Unlocking Charm
    C: Use Avada Kedavra\n""")
    
    choice_5 = input(prompt = "> Please enter your answer\n")
    choice_5 = choice_5.casefold()
    
    if 'parseltongue' in choice_5 or choice_5.lower() == 'a':
        print("""
Congratulations!
You have successfully found the entrance to the Chamber of Secrets.""")
        chamber_1() # Move to next stage
        
    elif 'unlocking' in choice_5 or choice_5.lower() == 'b':
        print("""
Unfortunately, this charm didn't work.""")
        bathroom_2() # Try again
        
    elif 'avada' in choice_5 or 'kedavra' in choice_5:
        print("""
Since the Avada Kedavra you used belongs to Unforgivable Curses, you are
imprisoned in Azkaban.""")
        fail() # Bad End 1: Do not use the Unforgivable Curses
        
    elif choice_5.lower() == 'c':
        print("""
Since the Avada Kedavra you used belongs to Unforgivable Curses, you are
imprisoned in Azkaban.""")
        fail() # Bad End 1: Do not use the Unforgivable Curses

    else:
        print("""
It doesn't look like you got the charm right.
Please listen carefully in the Charms class in the future.""")
        bathroom_2() # Back to the question
            

            
# Stage 3_1: Into the Chamber           
def chamber_1():
    print("""
When you arrive at the Chamber of Secrets, you see Ginny, passed out on the 
floor, and a strange Slytherin student, Tom Riddle.

Through the dialogue, you get that he is Voldemort's 16-year-old soul. He claims
he will become the greatest wizard of all time.

How would you reply to him?
    A: Mocking Tom what he is not going to achieve.
    B: Rebuttal Tom that Albus Dumbledore is the greatest wizard. """)
    
    choice_6 = input(prompt = "> Please enter your answer \n")
    choice_6 = choice_6.casefold()
    
    if choice_6.lower() == 'a' or 'mock' in choice_6:
        print("""
You succeeded in angering Tom. He summons Basilisk，the king of Serpents. 
In order not to meet its eyes, you hastily dodge and try to fight back. 
Unfortunately, you were defeated.""")
        fail() # Bad End 2: Loyalty
     
    elif choice_6.lower() == 'b':
        print("""
Tom summons Basilisk，the king of Serpents. In order not to meet its eyes, 
you hastily dodge and try to fight back. 
In the heat of the moment, the Phoenix Fawkes suddenly appeared because you 
showed your loyalty to Albus Dumbledore and brought the Sorting Hat to you!""")
        chamber_2() # Move to next step
    
    elif 'rebuttal' in choice_6 or 'albus' in choice_6 or 'aumbledore' in choice_6:
        print("""
Tom summons Basilisk，the king of Serpents. In order not to meet its eyes, 
you hastily dodge and try to fight back. 
In the heat of the moment, the Phoenix Fawkes suddenly appeared because you 
showed your loyalty to Albus Dumbledore and brought the Sorting Hat to you!""")
        chamber_2() # Move to next step
        
    else:
        print("Unable to read the answer! Please enter again.")
        chamber_1() # Back to the question


# Stage 3_2: Fight with the Basilisk      
def chamber_2():
    print("""
You are curious as to why Fawkes brought the Sorting Hat, so you approach to 
check it out. Surprisingly you find the Sword of Gryffindor in the hat! 
The sword makes you a much better fighter against the Basilisk. 

At the same time, Fawkes flew at Basilisk and caught it blind.
With a sword in hand, you choose to thrust it to:
    A: The Basilisk
    B: Tom Riddle""")
    
    choice_7 = input(prompt = "> Please enter your answer \n")
    choice_7 = choice_7.casefold()
    
    # Choose to fight against Basilisk
    if choice_7.lower() == 'a' or 'basilisk' in choice_7:
        print("""
Since Basilisk has gone blind, you can finally face it straight on and stab the
vitals. But at the same time, you are also bitten by the poisonous teeth.

Finally, you defeated the Basilisk but were poisoned at the same time. 
To slow down the poisoning, you pull out the poisonous teeth. 

Looking at the diary at your feet, you choose to: 
    A: Stab the poisonous tooth hardly into the diary.
    B: Keep the poisonous tooth for later.""")
        
        choice_8 = input(prompt = "> Please enter your answer \n")
        choice_8 = choice_8.casefold()
        
        # Destroy the diary
        if choice_8.lower() == 'a':
            print("""
Since the diary is one of the Horcruxes of Voldemort, Tom disappeared with it 
after the poisonous tooth destroyed it.""")
            end() # Move to the ture end
            
        elif 'stab' in choice_8 or 'diary' in choice_8:
            print("""
Since the diary is one of the Horcruxes of Voldemort, Tom disappeared with it 
after the poisonous tooth destroyed it.""")
            end() # Move to the ture end
            
        elif choice_8.lower == 'b':
            print("""
In the poisoned state, you are no match for Tom and eventually die of poisoning.""")
            fail() # Bad End 3: Do not hesitate
        
        # Keep poisoning
        elif 'keep' in choice_8 or 'later' in choice_8:
            print("""
In the poisoned state, you are no match for Tom and eventually die of poisoning.""")
            fail() # Bad End 3: Do not hesitate
            
        else:
            print("Unable to read the answer! Please enter again.")
            chamber_2() # Back to the question
            
    elif chioce_7.lower() == 'b' or 'tom' in choice_7 or 'riddle' in choice_7:
        print("""
While Fawkes and Basilisk were fighting, you took the opportunity to thrust your 
sword at Tom. Sadly, Basilisk quickly got out of the tangle. You could not resist 
the simultaneous attacks of Tom and Basilisk and were defeated.""")
        fail() # Bad End 4: Choose the right target
        
    else:
        print("Unable to read the answer! Please enter again.")
        chamber_2() # Back to the question

# Stage 4: The End        
def end():
    print("""
Congratulations!! 
You successfully defeated Basilisk, the king of Serpents, and saved Ginny Weasley! 
At the end of the story, Fawkes helps you to leave the Chamber of Secrets.

Good luck with your studies at Hogwarts this coming semester!!""") 
    input(prompt = "<Press any key to exit.>\n")
    exit(0)

# All bad ends will go to fail    
def fail(): 
    print("""
GAME OVER.
You did not pass this game. If you like the game welcome to play again!\n""")
    input(prompt = "<Press any key to exit.>\n")
    exit(0)            
            
start()
